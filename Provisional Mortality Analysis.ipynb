# %% [markdown]
# <a id="2"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:center;display:fill;border-radius:5px;background-color:#4e5825;overflow:hidden"><b>🦠 Provisional Mortality Analysis 🦠</b></div>

# %% [markdown]
# ----

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;over}flow:hidden"><b> 🎬 Introduction 🎬</b></div>

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:17px">
#
#
#
# <h3 align="left"><font color=purple>📝 Brief Summary of Data:</font></h3><br>
#
#
#
# * The dataset tracks <b>mortality percentages</b> associated with <b>COVID-19</b>, <b>Influenza</b>, and <b>RSV</b> on a <b>weekly</b> basis.<br>
# <br>
# * Key attributes include <b>week_end</b> (end date of the week), <b>pathogen</b> type, and <b>percent_deaths</b> (percentage of deaths).<br>
# <br>
# * This data aids in <b>monitoring</b> and <b>analyzing</b> the impact of respiratory pathogens on mortality trends.<br>
# <br>
# * Valuable for <b>epidemiological studies</b> and <b>public health decision-making</b>, informing health interventions and responses.  <br>
# <br>
# * This data from the data.gov website. You can access the dataset at the following link:
#     <a href="https://catalog.data.gov/dataset/provisional-percent-of-deaths-for-covid-19-influenza-and-rsv">Electric Vehicle Population Data</a>
#
#     <br>
#     <br>
#
#
# <h3 align="left"><font color=purple>📝 Research Questions:</font></h3><br>
#
# * Is there a <b>seasonal pattern</b> in the number of deaths from these pathogens <b>over time</b>?<br>
# <br>
# * What is the <b>comparative impact</b> of different pathogens on <b>mortality rates</b>?<br>
# <br>
# * What are the <b>mortality rate trends during transitional months?</b><br></div>

# %% [markdown]
# ---

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#4e5825;overflow:hidden"><b> 📚 Importing Libraries 📚</b></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
sns.set(style="darkgrid",font_scale=1.5)

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#4e5825;overflow:hidden"><b>⏳ Loading Datset ⏳</b></div>

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\Provisional_Percent_of_Deaths_for_COVID-19__Influenza__and_RSV.csv")
df.head()
# Out:
#      week_end   pathogen  percent_deaths
# 0  2018-01-06        RSV             0.0
# 1  2018-01-06  Influenza             1.8
# 2  2018-01-06   COVID-19             0.0
# 3  2018-01-13        RSV             0.0
# 4  2018-01-13  Influenza             2.3

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#4e5825;overflow:hidden"><b>🧾 Features Description 🧾</b></div>

# %% [markdown]
# | S.No | Attribute Name | Meaning |
# |:---| :--- |:--- |
# | 1 | week_end | The end date of the reported week |
# | 2 | pathogen | The type of pathogen or virus, such as RSV, Influenza, or COVID-19 |
# | 3 | percent_deaths | The percentage of deaths attributed to the respective pathogen for the specific week |

# %% [markdown]
# ---

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#4e5825;overflow:hidden"><b>📊 Data Summary. 📊</b></div>

# %% [markdown]
# ### 1. Computing the Dimension of Dataset.

# %%
df.shape
# Out:
# (703, 3)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>💬 Inference:</font></h3>
#
# 1. There are total <b>703 Records/Rows</b> in the dataset.<br>
# 2. There are total <b>3 Features/columns</b> in the dataset.<br></div>

# %% [markdown]
# ### 2. Generating Basic Information of Attributes.

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 703 entries, 0 to 702
# Columns: 3 entries, week_end to percent_deaths
# dtypes: float64(1), object(2)
# memory usage: 16.6+ KB

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. There are only <b>1 Numerical Attributes</b> in the dataset.<br>
# 2. On the other hand we have <b>2 Categorical Attributes.</b><br></div>

# %% [markdown]
# ### 3. Checking if There's Any Duplicate Records.

# %%
have_duplicate_rows = df.duplicated().any()
have_duplicate_rows
# Out:
# False

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. Since the <b>output is False, we can say that there's No Duplicate</b> Records present in the Dataset.<br></div>

# %% [markdown]
# ### 4. Checking Data-Types of Features.

# %%
df.dtypes.to_frame().rename(columns={0:"Data-Type"})
# Out:
#                Data-Type
# week_end          object
# pathogen          object
# percent_deaths   float64

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. There are only <b>1 Numerical Attributes</b> in the dataset.<br>
# 2. On the other hand we have <b>2 Categorical Attributes.</b><br></div>

# %% [markdown]
# ### 5. Checking Unique Values of Categorical Attributes.

# %%
cat_cols = df.select_dtypes(include="O").columns

for column in cat_cols:
    print('No. of Unique values in', column,"is:",df[column].nunique())
    print("-"*127)
# Out:
# No. of Unique values in week_end is: 301
# -------------------------------------------------------------------------------------------------------------------------------
# No. of Unique values in pathogen is: 3
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. Columns name weekend having high cardinalities.</b><br>
# 2. All the others columns are having <b>low cardinality.</b>

# %% [markdown]
# ### 6. Converting Date Column to Data-Type

# %%
df["week_end"] = pd.to_datetime(df["week_end"])

# %% [markdown]
# ### 6. Computing Total No. of Missing Values and the Percentage of Missing Values.

# %%
missing_df = df.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})
missing_df["% of Missing Values"] = round((missing_df["Total No. of Missing Values"]/len(df))*100,2)
missing_df
# Out:
#                 Total No. of Missing Values  % of Missing Values
# week_end                                  0                  0.0
# pathogen                                  0                  0.0
# percent_deaths                            0                  0.0

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. There are <b>No missing values.</b>

# %% [markdown]
# ---

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#4e5825;overflow:hidden"><b>📊 Exploratory Data Analysis.📊</b></div>

# %% [markdown]
# ### 1. Is there a seasonal pattern in the number of deaths from these pathogens over time.?

# %%
plt.figure(figsize=(13, 6))
sns.lineplot(x='week_end', y='percent_deaths', hue='pathogen', data=df)
plt.title('Trend Analysis of Pathogen Deaths Over Time')
plt.xlabel('Week End')
plt.ylabel('Percent Deaths')
plt.xticks(rotation=45)
plt.legend(title='Pathogen', loc='upper right')
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. <b>Consistent Influenza and RSV</b>: The analysis highlights the <b>consistency</b> in the percent deaths from Influenza and RSV over time. These pathogens maintain relatively <b>stable mortality rates</b> during the observed period.<br>
# <br>
# 2. <b>Fluctuating COVID-19</b>: In contrast to Influenza and RSV, COVID-19 exhibits a <b>fluctuating trend</b> in percent deaths. The data shows <b>varying impacts</b> of COVID-19 on mortality rates during the same period.

# %% [markdown]
# ----

# %% [markdown]
# ### 2. What is the comparative impact of different pathogens on mortality rates?

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='pathogen', y='percent_deaths', data=df)
plt.title('Comparative Analysis of Pathogen Impact on Mortality Rates')
plt.xlabel('Pathogen')
plt.ylabel('Percent Deaths')
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. The <b>Impact of COVID-19</b>: The bar graph illustrates that the <b>impact of COVID-19</b> on mortality rates is <b>significant</b>, as the bar representing COVID-19 is the <b>largest</b> among the three pathogens. This suggests that COVID-19 has a substantial influence on mortality during the observed period.<br>
# <br>
#
# 2. <b>Influenza's Influence</b>: In contrast, the bar representing Influenza is relatively <b>smaller</b>, indicating a <b>lesser impact</b> on mortality rates compared to COVID-19. It is worth noting that the bar for Influenza is visually smaller than COVID-19.<br>
# <br>
# 3. <b>Negligible Impact of RSV</b>: The bar representing RSV is almost <b>negligible</b> in comparison to both COVID-19 and Influenza. This suggests that, during the observed period, RSV has a <b>minimal impact</b> on mortality rates, with the bar being barely visible on the graph.<br>

# %% [markdown]
# ---

# %% [markdown]
# ### 3. What are the mortality rate trends during transitional months?"

# %%
df['month'] = df['week_end'].dt.month_name()
average_deaths_by_month = df.groupby('month')['percent_deaths'].mean().reset_index()

plt.figure(figsize=(14, 6))
plt.bar(average_deaths_by_month['month'], average_deaths_by_month['percent_deaths'], color='lightblue')
plt.title('Average Percent Deaths by Month')
plt.xlabel('Month')
plt.ylabel('Average Percent Deaths')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. Seasonal Variation: Mortality rates exhibit a <b>seasonal pattern</b>, with higher percentages during <b>winter months</b> (January, December, February) and lower percentages in <b>summer months</b> (June, July, August).<br>
# <br>
# 2. Low Mortality in Summer: Mortality rates are notably <b>lower during summer months</b>, indicating a potential relationship between warmer weather and reduced mortality.<br>
# <br>
# 3. Transitional Periods: Months like March, April, May, September, October, and November show <b>intermediate mortality rates</b>, possibly representing transition periods between high winter mortality and low summer mortality.<br>

# %% [markdown]
# ---

# %% [markdown]
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#4e5825;overflow:hidden"><b>🎈 Conclusion 🎈</b></div>

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Key Findings:</font></h3>
#
# 1. <b>Seasonal Patterns</b>: The data exhibits clear <b>seasonal patterns</b> in mortality rates, with <b>winter months</b> (January, December, February) having higher average percentages of deaths, while <b>summer months</b> (June, July, August) show notably lower mortality.<br>
# <br>
# 2. <b>Weather Impact</b>: The findings suggest a potential relationship between <b>weather and mortality</b>, with higher mortality rates during colder months and lower rates during warmer months, supporting the idea that weather can influence disease transmission.<br>
# <br>
# 3. <b>Transitional Periods</b>: Months like March, April, May, September, October, and November represent <b>transition periods</b> with intermediate average mortality rates, possibly due to the shift from one season to another.<br>
# <br>
# 4. <b>Public Health Implications</b>: Recognizing these <b>seasonal variations</b> can help public health officials and healthcare systems better prepare for and respond to <b>seasonal health challenges</b>, such as respiratory illnesses during winter.<br>
# <br>
# 5. <b>Further Investigation</b>: While the data provides valuable insights into mortality patterns, <b>further investigation</b> is necessary to understand the specific factors contributing to the observed trends and their implications for healthcare planning and disease prevention.<br>

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#4e5825;overflow:hidden"><b>🎈 References  🎈</b></div>

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
#
#
# 1. Sahoo, K., Samal, A. K., Pramanik, J., & Pani, S. K. (2019). Exploratory data analysis using Python. International Journal of Innovative Technology and Exploring Engineering, 8(12), 4727-4735.
# <br>
#
# 2. Rahmany, M., Zin, A. M., & Sundararajan, E. A. (2020). Comparing tools provided by python and r for exploratory data analysis. IJISCS Int. J. Inf. Syst. Comput. Sci, 4(3).
#
# 3. Sarkar, T. (2022). How to use python data science packages more productively. In Productive and Efficient Data Science with Python: With Modularizing, Memory profiles, and Parallel/GPU Processing (pp. 47-84). Berkeley, CA: Apress.
